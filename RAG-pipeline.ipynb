# %%
# !pip install -r generation_requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 60.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.6/302.6 kB 36.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 72.5 MB/s eta 0:00:00

# %%
from generate import askLLM

query = "multi fruit smoothie"

output_text = askLLM(query)
# Out:
# User is already logged in.
# tokenizer_config.json:   0%|          | 0.00/34.2k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/693 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/2.11G [00:00<?, ?B/s]
# `config.hidden_act` is ignored, you should use `config.hidden_activation` instead.
# Gemma's activation function will be set to `gelu_pytorch_tanh`. Please, use
# `config.hidden_activation` if you want to override this behaviour.
# ...

# %%
print(output_text)
# Out:
# <bos>**Relevant passages:**
#
# The text describes various recipes, including a multi-fruit smoothie. The recipe for the multi-fruit smoothie is as follows:
#
# **Ingredients:**
# - 2 cups frozen unsweetened strawberries
# - ½ cup blueberries
# - 1 banana cut in chunks
# - ½ kiwi, sliced
# - 2 cups fresh spinach
# - ½ cup ice cubes
# - 1 cup fat-free milk
# - ½ cup 100-percent apple juice
#
# **Instructions:**
# 1. Combine strawberries, blueberries, banana, kiwi, spinach, ice cubes, fat-free milk and apple juice in blender.
# 2. Blend until smooth.
#
# **Answer:**
#
# The text describes a multi-fruit smoothie recipe that includes strawberries, blueberries, banana, kiwi, spinach, ice cubes, fat-free milk, and apple juice. To make the smoothie, the ingredients are combined in a blender and blended until smooth.<eos>
